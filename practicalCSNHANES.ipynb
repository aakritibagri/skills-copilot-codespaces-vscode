# %% [markdown]
# <a href="https://colab.research.google.com/github/aakritibagri/skills-copilot-codespaces-vscode/blob/main/practicalCSNHANES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# Reading the CSV file
df = pd.read_csv("nhanes_2015_2016.csv")
print(df)
# Out:
#        SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0     83732     1.0     NaN     1.0       1         1        62         3
# 1     83733     1.0     NaN     6.0       1         1        53         3
# 2     83734     1.0     NaN     NaN       1         1        78         3
# 3     83735     2.0     1.0     1.0       2         2        56         3
# 4     83736     2.0     1.0     1.0       2         2        42         4
# ...     ...     ...     ...     ...     ...       ...       ...       ...
# 5730  93695     2.0     2.0     NaN       1         2        76         3
# 5731  93696     2.0     2.0     NaN       2         1        26         3
# 5732  93697     1.0     NaN     1.0       1         2        80         3
# 5733  93700     NaN     NaN     NaN       1         1        35         3
# 5734  93702     1.0     NaN     2.0       2         2        24         3
#
#       DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# ...

# %%
df.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1       2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2       1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 3       1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4       1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# ...

# %%
df.tail()
# Out:
#        SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 5730  93695     2.0     2.0     NaN       1         2        76         3
# 5731  93696     2.0     2.0     NaN       2         1        26         3
# 5732  93697     1.0     NaN     1.0       1         2        80         3
# 5733  93700     NaN     NaN     NaN       1         1        35         3
# 5734  93702     1.0     NaN     2.0       2         2        24         3
#
#       DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 5730       1.0       3.0  ...   112.0    46.0   59.1  165.8    21.5    38.2
# 5731       1.0       5.0  ...   116.0    76.0  112.1  182.2    33.8    43.4
# 5732       1.0       4.0  ...   146.0    58.0   71.7  152.2    31.0    31.3
# 5733       2.0       1.0  ...   106.0    66.0   78.2  173.3    26.0    40.3
# 5734       1.0       5.0  ...   114.0    68.0   58.3  165.0    21.4    38.2
#
#       BMXARML  BMXARMC  BMXWAIST  HIQ210
# ...

# %%
df.shape
# Out:
# (5735, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5735 entries, 0 to 5734
# Data columns (total 28 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      5735 non-null   int64
#  1   ALQ101    5208 non-null   float64
#  2   ALQ110    1731 non-null   float64
#  3   ALQ130    3379 non-null   float64
#  4   SMQ020    5735 non-null   int64
#  5   RIAGENDR  5735 non-null   int64
#  6   RIDAGEYR  5735 non-null   int64
#  7   RIDRETH1  5735 non-null   int64
#  8   DMDCITZN  5734 non-null   float64
#  9   DMDEDUC2  5474 non-null   float64
#  10  DMDMARTL  5474 non-null   float64
#  11  DMDHHSIZ  5735 non-null   int64
#  12  WTINT2YR  5735 non-null   float64
#  13  SDMVPSU   5735 non-null   int64
#  14  SDMVSTRA  5735 non-null   int64
#  15  INDFMPIR  5134 non-null   float64
#  16  BPXSY1    5401 non-null   float64
#  17  BPXDI1    5401 non-null   float64
#  18  BPXSY2    5535 non-null   float64
#  19  BPXDI2    5535 non-null   float64
# ...

# %%
df.describe()
# Out:
#                SEQN       ALQ101       ALQ110       ALQ130       SMQ020  \
# count   5735.000000  5208.000000  1731.000000  3379.000000  5735.000000
# mean   88678.583435     1.336406     1.587522     3.911512     1.607149
# std     2882.139237     0.505514     0.623940    34.341839     0.571975
# min    83732.000000     1.000000     1.000000     1.000000     1.000000
# 25%    86164.000000     1.000000     1.000000     1.000000     1.000000
# 50%    88668.000000     1.000000     2.000000     2.000000     2.000000
# 75%    91178.500000     2.000000     2.000000     3.000000     2.000000
# max    93702.000000     9.000000     9.000000   999.000000     9.000000
#
#           RIAGENDR     RIDAGEYR     RIDRETH1     DMDCITZN     DMDEDUC2  ...  \
# count  5735.000000  5735.000000  5735.000000  5734.000000  5474.000000  ...
# mean      1.518919    48.052310     3.042371     1.185385     3.441725  ...
# std       0.499686    18.431011     1.296793     0.491678     1.309700  ...
# ...

# %%
df.isnull().sum()
# Out:
# SEQN           0
# ALQ101       527
# ALQ110      4004
# ALQ130      2356
# SMQ020         0
# RIAGENDR       0
# RIDAGEYR       0
# RIDRETH1       0
# DMDCITZN       1
# DMDEDUC2     261
# DMDMARTL     261
# DMDHHSIZ       0
# WTINT2YR       0
# SDMVPSU        0
# SDMVSTRA       0
# INDFMPIR     601
# BPXSY1       334
# BPXDI1       334
# BPXSY2       200
# BPXDI2       200
# BMXWT         69
# BMXHT         62
# BMXBMI        73
# BMXLEG       390
# BMXARML      308
# BMXARMC      308
# BMXWAIST     367
# HIQ210      1003
# dtype: int64

# %%
#columns of interest:
da = df.loc[: , ['SMQ020' , 'RIAGENDR','RIDAGEYR' , 'DMDMARTL', 'DMDEDUC2' ,'BMXWT', 'BMXBMI' , 'BMXHT' , 'BPXSY1']]
da.head()
# Out:
#    SMQ020  RIAGENDR  RIDAGEYR  DMDMARTL  DMDEDUC2  BMXWT  BMXBMI  BMXHT  \
# 0       1         1        62       1.0       5.0   94.8    27.8  184.5
# 1       1         1        53       3.0       3.0   90.4    30.8  171.4
# 2       1         1        78       1.0       3.0   83.4    28.8  170.1
# 3       2         2        56       6.0       5.0  109.8    42.4  160.9
# 4       2         2        42       3.0       4.0   55.2    20.3  164.9
#
#    BPXSY1
# 0   128.0
# 1   146.0
# 2   138.0
# 3   132.0
# 4   100.0

# %%
#Fixing the column names
da.columns = ['Smoking' , 'Gender' , 'Age' , 'Martial Statues' ,'Education Level' ,'Weight' , 'BMI', 'Height' , 'Systolic Blood Preasure']

# %%
# replace 1 and 2 in male and female
da["Gender"] = da.Gender.replace({1: "Male", 2: "Female"})

# %%
#Fixing the martial statues column and generating a frequency table
da["Martial Statues"] = da['Martial Statues'].replace({1: "Married", 2: "Widowed", 3: "Divorced", 4: "Separated", 5: "Never married",
                                      6: "Living w/partner", 77: "Refused"})
da["Martial Statues"].value_counts()
# Out:
# Married             2780
# Never married       1004
# Divorced             579
# Living w/partner     527
# Widowed              396
# Separated            186
# Refused                2
# Name: Martial Statues, dtype: int64

# %%
#Fixing the Smoking SMOQ020 column
da["Smoking"] = da['Smoking'].replace({1: "Yes", 2: "No" , 7: "Refused", 9:"Don't know "})
da["Smoking"].value_counts()
# Out:
# No             3406
# Yes            2319
# Don't know        8
# Refused           2
# Name: Smoking, dtype: int64

# %%
da.head()
# Out:
#   Smoking  Gender  Age   Martial Statues  Education Level  Weight   BMI  \
# 0     Yes    Male   62           Married              5.0    94.8  27.8
# 1     Yes    Male   53          Divorced              3.0    90.4  30.8
# 2     Yes    Male   78           Married              3.0    83.4  28.8
# 3      No  Female   56  Living w/partner              5.0   109.8  42.4
# 4      No  Female   42          Divorced              4.0    55.2  20.3
#
#    Height  Systolic Blood Preasure
# 0   184.5                    128.0
# 1   171.4                    146.0
# 2   170.1                    138.0
# 3   160.9                    132.0
# 4   164.9                    100.0

# %%
da[da.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Smoking, Gender, Age, Martial Statues, Education Level, Weight, BMI, Height, Systolic Blood Preasure]
# Index: []

# %%
da.isna().sum()
# Out:
# Smoking                      0
# Gender                       0
# Age                          0
# Martial Statues            261
# Education Level            261
# Weight                      69
# BMI                         73
# Height                      62
# Systolic Blood Preasure    334
# dtype: int64

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(x='Weight' , y='Height' , hue='Martial Statues' , data=da)
# Placing Legend outside the figure
plt.legend(bbox_to_anchor=(1,1), loc=2)
plt.show()

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt


sns.scatterplot(x='Height', y='Systolic Blood Preasure',
                hue='Education Level', data=da, )

# Placing Legend outside the Figure
plt.legend(bbox_to_anchor=(1, 1), loc=2)

plt.show()

# %%
da["agegrp"] = pd.cut(da.Age, [18, 30, 40, 50, 60, 70, 80])
plt.figure(figsize=(12, 5))
sns.boxplot(x="agegrp", y='Systolic Blood Preasure', hue="Gender", data=da);

# %%
sns.boxplot(x = da.Gender , y = da.Height);
print(f"average height of men {da[da.Gender =='Male'].Height.mean()} , while for women {da[da.Gender =='Female'].Height.mean()}")
# Out:
# average height of men 173.13204987165383 , while for women 159.6731839782756

# %%
db = da.loc[(da['Education Level'] != "Don't know") & (da["Martial Statues"] != "Refused"), :]
# creating a normalized contingency table, counting the number of people in each cell
# defined by a combination of education and marital status.
ct = pd.crosstab(db['Education Level'], da["Martial Statues"] ).apply(lambda x:x / x.sum(), axis = 1)
ct
# Out:
# Martial Statues  Divorced  Living w/partner   Married  Never married  \
# Education Level
# 1.0              0.079389          0.100763  0.520611       0.099237
# 2.0              0.096423          0.124417  0.474339       0.181960
# 3.0              0.107083          0.112142  0.463744       0.199831
# 4.0              0.134033          0.100679  0.467573       0.205065
# 5.0              0.087848          0.062225  0.605417       0.185212
# 9.0              0.333333          0.000000  0.000000       0.000000
#
# Martial Statues  Separated   Widowed
# Education Level
# 1.0               0.065649  0.134351
# 2.0               0.060653  0.062208
# 3.0               0.033727  0.083474
# 4.0               0.025942  0.066708
# 5.0               0.016105  0.043192
# 9.0               0.000000  0.666667

# %%
plt.figure(figsize=(12, 4))
a = sns.boxplot(x = db['Martial Statues'], y =db.Age)

# %%
# Creating a box plot for the 'income' variable.
sns.boxplot(x=da['Systolic Blood Preasure'])
plt.title('Box Plot of Systolic Blood Preasure ')
plt.xlabel('Systolic Blood Preasure')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.set(style="whitegrid")
sns.histplot(da['Age'], kde=True, color="skyblue")
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()
